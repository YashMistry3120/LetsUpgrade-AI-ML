# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


# %matplotlib inline

# %%
df = pd.read_csv('S:\LetsUpgrade\Day 7\Assignment\general_data_copy.csv')

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   51        No      Travel_Rarely                   Sales                 6
# 1   31       Yes  Travel_Frequently  Research & Development                10
# 2   32        No  Travel_Frequently  Research & Development                17
# 3   38        No         Non-Travel  Research & Development                 2
# 4   32        No      Travel_Rarely  Research & Development                10
#
#    Education EducationField  EmployeeCount  EmployeeID  Gender  ...  \
# 0          2  Life Sciences              1           1  Female  ...
# 1          1  Life Sciences              1           2  Female  ...
# 2          4          Other              1           3    Male  ...
# 3          5  Life Sciences              1           4    Male  ...
# 4          1        Medical              1           5    Male  ...
#
#    NumCompaniesWorked Over18 PercentSalaryHike  StandardHours  \
# ...

# %%
df.describe()
# Out:
#                Age  DistanceFromHome    Education  EmployeeCount   EmployeeID  \
# count  4410.000000       4410.000000  4410.000000         4410.0  4410.000000
# mean     36.923810          9.192517     2.912925            1.0  2205.500000
# std       9.133301          8.105026     1.023933            0.0  1273.201673
# min      18.000000          1.000000     1.000000            1.0     1.000000
# 25%      30.000000          2.000000     2.000000            1.0  1103.250000
# 50%      36.000000          7.000000     3.000000            1.0  2205.500000
# 75%      43.000000         14.000000     4.000000            1.0  3307.750000
# max      60.000000         29.000000     5.000000            1.0  4410.000000
#
#           JobLevel  MonthlyIncome  NumCompaniesWorked  PercentSalaryHike  \
# count  4410.000000    4410.000000         4391.000000        4410.000000
# mean      2.063946   65029.312925            2.694830          15.209524
# ...

# %%
df['Attrition'].replace(to_replace=("No","Yes"),value=(0,1),inplace=True)

# %%
df = df.dropna()
df = df.drop_duplicates()
df
# Out:
#       Age  Attrition     BusinessTravel              Department  \
# 0      51          0      Travel_Rarely                   Sales
# 1      31          1  Travel_Frequently  Research & Development
# 2      32          0  Travel_Frequently  Research & Development
# 3      38          0         Non-Travel  Research & Development
# 4      32          0      Travel_Rarely  Research & Development
# ...   ...        ...                ...                     ...
# 4404   29          0      Travel_Rarely                   Sales
# 4405   42          0      Travel_Rarely  Research & Development
# 4406   29          0      Travel_Rarely  Research & Development
# 4407   25          0      Travel_Rarely  Research & Development
# 4408   42          0      Travel_Rarely                   Sales
#
#       DistanceFromHome  Education EducationField  EmployeeCount  EmployeeID  \
# 0                    6          2  Life Sciences              1           1
# ...

# %%
df.corr()
# Out:
#                               Age  Attrition  DistanceFromHome  Education  \
# Age                      1.000000  -0.158399          0.007376  -0.033900
# Attrition               -0.158399   1.000000         -0.009449  -0.017106
# DistanceFromHome         0.007376  -0.009449          1.000000  -0.007491
# Education               -0.033900  -0.017106         -0.007491   1.000000
# EmployeeCount                 NaN        NaN               NaN        NaN
# EmployeeID               0.008105  -0.004621         -0.000326  -0.009389
# JobLevel                -0.001137  -0.012382         -0.039990   0.045822
# MonthlyIncome           -0.045163  -0.030160         -0.022757   0.007289
# NumCompaniesWorked       0.299527   0.042831         -0.014449  -0.016210
# PercentSalaryHike       -0.032561   0.033153          0.037720  -0.041054
# StandardHours                 NaN        NaN               NaN        NaN
# StockOptionLevel        -0.031504  -0.008164          0.009353   0.002386
# ...

# %%
from scipy.stats import pearsonr
#p_value < 0.05 Reject H0
#p_value > 0.05 Do Not Reject H0 or Accepted

# %% [markdown]
# ### Correlation Between Attrition and Age

# %%
stats,p = pearsonr(df.Attrition,df.Age)
print("Correlation: ",stats,"\nP-Value: ",p)

if p<0.05:
    print("\n\nReject Null Hypothises")
else:
    print("\n\nAccept Null Hypothises")
# Out:
# Correlation:  -0.15839867954096706
# P-Value:  5.1265982193780794e-26
#
#
# Reject Null Hypothises

# %%
SampleData = df.sample(30)
plt.scatter(SampleData.Attrition,SampleData.Age)

# %% [markdown]
# ### Correlation Between Attrition and Distance_from_Home

# %%
stats,p = pearsonr(df.Attrition,df.DistanceFromHome)
print("Correlation: ",stats,"\nP-Value: ",p)

if p<0.05:
    print("\n\nReject Null Hypothises")
else:
    print("\n\nAccept Null Hypothises")
# Out:
# Correlation:  -0.009448638515156243
# P-Value:  0.5317715668019558
#
#
# Accept Null Hypothises

# %%
SampleData = df.sample(30)
plt.scatter(SampleData.Attrition,SampleData.DistanceFromHome)

# %% [markdown]
# ### Correlation Between Eduction and Attrition

# %%
stats,p = pearsonr(df.Attrition,df.Education)
print("Correlation: ",stats,"\n P-Value: ",p)
if p<0.05:
    print("\n\nReject Null Hypothises")
else:
    print("\n\nAccept Null Hypothises")
# Out:
# Correlation:  -0.017106307050278727
#  P-Value:  0.25757539308157945
#
#
# Accept Null Hypothises

# %%
SampleData = df.sample(30)
plt.scatter(SampleData.Attrition,SampleData.Education)

# %% [markdown]
# ### Correlation Between Attrition and MonthlyIncome

# %%
stats,p = pearsonr(df.Attrition,df.MonthlyIncome)
print("Correlation: ",stats,"\n P-Value: ",p)
if p<0.05:
    print("\n\nReject Null Hypothises")
else:
    print("\n\nAccept Null Hypothises")
# Out:
# Correlation:  -0.030160293808460668
#  P-Value:  0.045890862744719166
#
#
# Reject Null Hypothises

# %%
SampleData = df.sample(30)
plt.scatter(SampleData.Attrition,SampleData.MonthlyIncome)

# %% [markdown]
# ### Correlation Between Attrition and YearsWithCurrManager

# %%
stats,p = pearsonr(df.Attrition,df.YearsWithCurrManager)
print("Correlation: ",stats,"\n P-Value: ",p)
if p<0.05:
    print("\n\nReject Null Hypothises")
else:
    print("\n\nAccept Null Hypothises")
# Out:
# Correlation:  -0.15469153690287274
#  P-Value:  7.105369646771178e-25
#
#
# Reject Null Hypothises

# %%
SampleData = df.sample(30)
plt.scatter(SampleData.Attrition,SampleData.YearsWithCurrManager)

# %% [markdown]
# ### Correlation Between Age and Education

# %%
stats,p = pearsonr(df.Age,df.Education)
print("Correlation: ",stats,"\n P-Value: ",p)
if p<0.05:
    print("\n\nReject Null Hypothises")
else:
    print("\n\nAccept Null Hypothises")
# Out:
# Correlation:  -0.033900022098179695
#  P-Value:  0.02482767033612246
#
#
# Reject Null Hypothises

# %%
SampleData = df.sample(30)
plt.scatter(SampleData.Age,SampleData.Education)

# %% [markdown]
# ### Correlation Between MonthlyIncome and Education

# %%
stats,p = pearsonr(df.MonthlyIncome,df.Education)
print("Correlation: ",stats,"\n P-Value: ",p)
if p<0.05:
    print("\n\nReject Null Hypothises")
else:
    print("\n\nAccept Null Hypothises")
# Out:
# Correlation:  0.0072893637499505375
#  P-Value:  0.629521537432801
#
#
# Accept Null Hypothises

# %%
SampleData = df.sample(20)
plt.scatter(SampleData.MonthlyIncome,SampleData.Education)

# %% [markdown]
# ### Correlation Between Education and NumCompaniesWorked

# %%
stats,p = pearsonr(df.NumCompaniesWorked,df.Education)
print("Correlation: ",stats,"\n P-Value: ",p)
if p<0.05:
    print("\n\nReject Null Hypothises")
else:
    print("\n\nAccept Null Hypothises")
# Out:
# Correlation:  -0.016210339453101862
#  P-Value:  0.28334517989260916
#
#
# Accept Null Hypothises

# %%
SampleData = df.sample(20)
plt.scatter(SampleData.NumCompaniesWorked,SampleData.Education)
